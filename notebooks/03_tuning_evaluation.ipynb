# %% [markdown]
# # 3.0 Setup & Loading Cleaned Data
#
# ---

# %%
# import neccesary libraries
# import same cleaned alchohol data from 2.X

# %% [markdown]
# # 3.1 Cross Validation of Current Model
#
# ---

# %%
# Confirm 2.5's tuned settings are stable across folds, not just one lucky split

# %% [markdown]
# # 3.2 Systematic Hyperparameter Search
#
# ---

# %%
# Formalize the manual grid search from 02 using GridSearchCV, now with cross-validation

# %% [markdown]
# # 3.3 Addressing High Risk Recall
#
# ---

# %%
# Test class_weight="balanced" and/or threshold adjustment, compare against 02's baseline

# %% [markdown]
# # 3.4 Final Model Selection
#
# ---

# %%
# Reasoning cell comparing all tested variants, lock in the model going to the prototype

# %% [markdown]
# # 3.5 Exporting Final Model
#
# ---

# %% [markdown]
# # 3.6 Summary & Next Steps
